# %% [markdown]
# ## Data from EQ-evolution

# %%
# %matplotlib inline

from math import *
import matplotlib
import numpy as np
import matplotlib.transforms as transforms
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pylab
from scipy import interpolate
import os
text_size=26
fig_size_x=24
fig_size_y=14

import seaborn as sns
Colors = sns.color_palette("colorblind", 16).as_hex()

from collections import defaultdict

def nested_dict(n, type):
    if n == 1:
        return defaultdict(type)
    else:
        return defaultdict(lambda: nested_dict(n-1, type))
    
data = nested_dict(5, list)

# %%
# address_ref='/Users/farbod/Packages/gevolution-1.1/output/'
address_ref2='/Users/farbod/Packages/gevolution-1.2/output/'
redshifts=[100];

add2= "/Users/farbod/Packages/tests_EQ_evolution/EQevolution_test/output"
add3= "/Users/farbod/Packages/tests_EQ_evolution/KGBevolution_test//output"

address_ref_kgb='/Users/farbod/Packages/gevolution-1.2/output/'

for i in range(np.shape(redshifts)[0]):
    data['eq_ev']['pi']['z='+str(redshifts[i])] = np.loadtxt("./../output/lcdm_pk00"+str(i)+"_pi.dat")
    data['eq_ev']['V_pi']['z='+str(redshifts[i])] = np.loadtxt("./../output/lcdm_pk00"+str(i)+"_V_pi.dat")
    data['eq_ev']['m']['z='+str(redshifts[i])] = np.loadtxt("./../output/lcdm_pk00"+str(i)+"_delta.dat")
    data['eq_ev']['phi']['z='+str(redshifts[i])] = np.loadtxt("./../output/lcdm_pk00"+str(i)+"_phi.dat")
    data['eq_ev']['chi']['z='+str(redshifts[i])] = np.loadtxt("./../output/lcdm_pk00"+str(i)+"_chi.dat")
    data['eq_ev']['hij']['z='+str(redshifts[i])] = np.loadtxt("./../output/lcdm_pk00"+str(i)+"_hij.dat")
    data['eq_ev']['B']['z='+str(redshifts[i])] = np.loadtxt("./../output/lcdm_pk00"+str(i)+"_B.dat")
    
    
    data['eq2']['pi']['z='+str(redshifts[i])] = np.loadtxt(add2+"/lcdm_pk00"+str(i)+"_pi.dat")
    data['eq2']['V_pi']['z='+str(redshifts[i])] = np.loadtxt(add2+"/lcdm_pk00"+str(i)+"_V_pi.dat")
    data['eq2']['m']['z='+str(redshifts[i])] = np.loadtxt(add2+"/lcdm_pk00"+str(i)+"_delta.dat")
    data['eq2']['phi']['z='+str(redshifts[i])] = np.loadtxt(add2+"/lcdm_pk00"+str(i)+"_phi.dat")
    data['eq2']['chi']['z='+str(redshifts[i])] = np.loadtxt(add2+"/lcdm_pk00"+str(i)+"_chi.dat")
    data['eq2']['hij']['z='+str(redshifts[i])] = np.loadtxt(add2+"/lcdm_pk00"+str(i)+"_hij.dat")
    data['eq2']['B']['z='+str(redshifts[i])] = np.loadtxt(add2+"/lcdm_pk00"+str(i)+"_B.dat")

#     data['kgb']['pi']['z='+str(redshifts[i])] = np.loadtxt("./../output/lcdm_pk00"+str(i)+"_pi.dat")
#     data['kgb']['V_pi']['z='+str(redshifts[i])] = np.loadtxt("./../output/lcdm_pk00"+str(i)+"_V_pi.dat")
    data['kgb']['m']['z='+str(redshifts[i])] = np.loadtxt("./../../KGBevolution/output/EFT_pk00"+str(i)+"_delta.dat")
    data['kgb']['phi']['z='+str(redshifts[i])] =np.loadtxt("./../../KGBevolution/output/EFT_pk00"+str(i)+"_phi.dat")
    data['kgb']['chi']['z='+str(redshifts[i])] = np.loadtxt("./../../KGBevolution/output/EFT_pk00"+str(i)+"_chi.dat")
    data['kgb']['hij']['z='+str(redshifts[i])] = np.loadtxt("./../../KGBevolution/output/EFT_pk00"+str(i)+"_hij.dat")
    data['kgb']['B']['z='+str(redshifts[i])] =np.loadtxt("./../../KGBevolution/output/EFT_pk00"+str(i)+"_B.dat")
        
    
#     data['kgb2']['pi']['z='+str(redshifts[i])] = np.loadtxt(add3+"/EFT_pk00"+str(i)+"_pi.dat")
#     data['kgb2']['V_pi']['z='+str(redshifts[i])] = np.loadtxt(add3+"/EFT_pk00"+str(i)+"_V_pi.dat")
    data['kgb2']['m']['z='+str(redshifts[i])] = np.loadtxt(add3+"/EFT_pk00"+str(i)+"_delta.dat")
    data['kgb2']['phi']['z='+str(redshifts[i])] = np.loadtxt(add3+"/EFT_pk00"+str(i)+"_phi.dat")
    data['kgb2']['chi']['z='+str(redshifts[i])] = np.loadtxt(add3+"/EFT_pk00"+str(i)+"_chi.dat")
    data['kgb2']['hij']['z='+str(redshifts[i])] = np.loadtxt(add3+"/EFT_pk00"+str(i)+"_hij.dat")
    data['ekgb2q2']['B']['z='+str(redshifts[i])] = np.loadtxt(add3+"/EFT_pk00"+str(i)+"_B.dat")
    
    # Ref runs
    data['ref2']['m']['z='+str(redshifts[i])] = np.loadtxt(address_ref2+"lcdm_pk00"+str(i)+"_delta.dat")
    data['ref2']['phi']['z='+str(redshifts[i])] = np.loadtxt(address_ref2+"lcdm_pk00"+str(i)+"_phi.dat")
    data['ref2']['chi']['z='+str(redshifts[i])] = np.loadtxt(address_ref2+"lcdm_pk00"+str(i)+"_chi.dat")
    data['ref2']['hij']['z='+str(redshifts[i])] = np.loadtxt(address_ref2+"lcdm_pk00"+str(i)+"_hij.dat")
    data['ref2']['B']['z='+str(redshifts[i])] = np.loadtxt(address_ref2+"lcdm_pk00"+str(i)+"_B.dat")

# %%
bg_eq= np.loadtxt("./../../EQ_hi_class/output/quin_background.dat")

bg_kgb= np.loadtxt("./../../hi_class_pub_devel/output/kgb_hiclass_background.dat")

# %% [markdown]
# # chi

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)

plt.figure(figsize=(15,12))

# Reference:

###### hiclass results:
l=0
for i in range(0,1):
    z=redshifts[i]

    k_h = data['eq_ev']['chi']['z='+str(redshifts[i])] [:,0]
    pk = data['eq_ev']['chi']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"o", color = Colors[l],markersize=8 , label = "EQ-evolution,  $\chi$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

    k_h = data['eq2']['chi']['z='+str(redshifts[i])] [:,0]
    pk = data['eq2']['chi']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"*", color = Colors[l+1],markersize=20,mfc='none' , label = "EQ-evolution2,  $\chi$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

    k_h = data['ref2']['chi']['z='+str(redshifts[i])] [:,0]
    pk = data['ref2']['chi']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),'s', color = Colors[l+2],mfc='none',markersize=15 , label = "gevolution2, Newtonian, z="+str(z), alpha=0.3)

    k_h = data['kgb']['chi']['z='+str(redshifts[i])] [:,0]
    pk = data['kgb']['chi']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"o", color = Colors[l+3],markersize=8 , label = "KGB,  $\chi$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

    k_h = data['kgb2']['chi']['z='+str(redshifts[i])] [:,0]
    pk = data['kgb2']['chi']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"^", color = Colors[l+4],markersize=20,mfc='none' , label = "KGB,  $\chi$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

# ########
#     k_q = data['class_tk']['z='+str(redshifts[i])][:,0];
#     tk = data['class_tk']['z='+str(redshifts[i])]
#     Normlization = As*(k_q/kp)**(ns-1.);
#     pk = (tk[:,8]-tk[:,9])**2*Normlization ## chi = phi-psi
# #     Normlization = As*(k_q/kp)**(ns-1.);
#     plt.plot(k_q, pk,"-.", color = Colors[l+2] , label = r"Synchronous, hiclass, tk, z="+str(z))

    l=l+1
    


plt.legend()
plt.ylabel(r"$\mathcal{P}$")
plt.xlabel(r"$k[h/Mpc]$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.e-4,1.e0)
plt.ylim(1.e-25,1.e-8)
# Out:
# (1e-25, 1e-08)

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)

plt.figure(figsize=(15,12))

# Reference:

###### hiclass results:
l=0
for i in range(0,1):
    z=redshifts[i]

    k_h = data['eq_ev']['hij']['z='+str(redshifts[i])] [:,0]
    pk = data['eq_ev']['hij']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"o", color = Colors[l],markersize=8 , label = "EQ-evolution,  $hij$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

    k_h = data['eq2']['hij']['z='+str(redshifts[i])] [:,0]
    pk = data['eq2']['hij']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"*", color = Colors[l+1],markersize=20,mfc='none' , label = "EQ-evolution2,  $hij$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)


    k_h = data['ref2']['hij']['z='+str(redshifts[i])] [:,0]
    pk = data['ref2']['hij']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),'s', color = Colors[l+2],mfc='none',markersize=15 , label = "gevolution2, Newtonian, z="+str(z), alpha=0.3)

    k_h = data['kgb']['hij']['z='+str(redshifts[i])] [:,0]
    pk = data['kgb']['hij']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"o", color = Colors[l+3],markersize=8 , label = "KGB,  $hij$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

    k_h = data['kgb2']['hij']['z='+str(redshifts[i])] [:,0]
    pk = data['kgb2']['hij']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"^", color = Colors[l+4],markersize=20,mfc='none' , label = "KGB,  $hij$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

# ########
#     k_q = data['class_tk']['z='+str(redshifts[i])][:,0];
#     tk = data['class_tk']['z='+str(redshifts[i])]
#     Normlization = As*(k_q/kp)**(ns-1.);
#     pk = (tk[:,8]-tk[:,9])**2*Normlization ## chi = phi-psi
# #     Normlization = As*(k_q/kp)**(ns-1.);
#     plt.plot(k_q, pk,"-.", color = Colors[l+2] , label = r"Synchronous, hiclass, tk, z="+str(z))

    l=l+1
    


plt.legend()
plt.ylabel(r"$\mathcal{P}$")
plt.xlabel(r"$k[h/Mpc]$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.e-4,1.e0)
plt.ylim(1.e-25,1.e-8)
# Out:
# (1e-25, 1e-08)

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)

plt.figure(figsize=(15,12))

# Reference:

###### hiclass results:
l=0
for i in range(0,1):
    z=redshifts[i]

    k_h = data['eq_ev']['B']['z='+str(redshifts[i])] [:,0]
    pk = data['eq_ev']['B']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"*", color = Colors[l],markersize=15 , label = "EQ-evolution,  $Bi$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

    k_h = data['ref2']['B']['z='+str(redshifts[i])] [:,0]
    pk = data['ref2']['B']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),'s', color = Colors[l+2],mfc='none',markersize=15 , label = "gevolution2, Newtonian, z="+str(z), alpha=0.3)

    k_h = data['kgb']['B']['z='+str(redshifts[i])] [:,0]
    pk = data['kgb']['B']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"o", color = Colors[l+3],markersize=8 , label = "KGB,  $Bi$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

# ########
#     k_q = data['class_tk']['z='+str(redshifts[i])][:,0];
#     tk = data['class_tk']['z='+str(redshifts[i])]
#     Normlization = As*(k_q/kp)**(ns-1.);
#     pk = (tk[:,8]-tk[:,9])**2*Normlization ## chi = phi-psi
# #     Normlization = As*(k_q/kp)**(ns-1.);
#     plt.plot(k_q, pk,"-.", color = Colors[l+2] , label = r"Synchronous, hiclass, tk, z="+str(z))

    l=l+1
    


plt.legend()
plt.ylabel(r"$\mathcal{P}$")
plt.xlabel(r"$k[h/Mpc]$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.e-4,1.e0)
plt.ylim(1.e-25,1.e-8)
# Out:
# (1e-25, 1e-08)

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)

plt.figure(figsize=(15,12))

# Reference:

###### hiclass results:
l=0
for i in range(0,1):
    z=redshifts[i]

    k_h = data['eq_ev']['phi']['z='+str(redshifts[i])] [:,0]
    pk = data['eq_ev']['phi']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"o", color = Colors[l],markersize=8 , label = "EQ-evolution,  $\Phi$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

    k_h = data['ref2']['phi']['z='+str(redshifts[i])] [:,0]
    pk = data['ref2']['phi']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),'s', color = Colors[l+2],mfc='none',markersize=15 , label = "gevolution2, Newtonian, z="+str(z), alpha=0.3)

    k_h = data['kgb']['phi']['z='+str(redshifts[i])] [:,0]
    pk = data['kgb']['phi']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"o", color = Colors[l+3],markersize=8 , label = "KGB,  $\Phi$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

# ########
#     k_q = data['class_tk']['z='+str(redshifts[i])][:,0];
#     tk = data['class_tk']['z='+str(redshifts[i])]
#     Normlization = As*(k_q/kp)**(ns-1.);
#     pk = (tk[:,8]-tk[:,9])**2*Normlization ## chi = phi-psi
# #     Normlization = As*(k_q/kp)**(ns-1.);
#     plt.plot(k_q, pk,"-.", color = Colors[l+2] , label = r"Synchronous, hiclass, tk, z="+str(z))

    l=l+1
    


plt.legend()
plt.ylabel(r"$\mathcal{P}$")
plt.xlabel(r"$k[h/Mpc]$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.e-4,1.e0)
plt.ylim(1.e-13,1.e-8)
# Out:
# (1e-13, 1e-08)

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)

plt.figure(figsize=(15,12))

# Reference:

###### hiclass results:
l=0
for i in range(0,1):
    z=redshifts[i]

    k_h = data['eq_ev']['m']['z='+str(redshifts[i])] [:,0]
    pk = data['eq_ev']['m']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"o", color = Colors[l],markersize=8 , label = "EQ-evolution,  $m$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

    k_h = data['ref2']['m']['z='+str(redshifts[i])] [:,0]
    pk = data['ref2']['m']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),'s', color = Colors[l+2],mfc='none',markersize=15 , label = "gevolution2, Newtonian, z="+str(z), alpha=0.3)

    k_h = data['kgb']['m']['z='+str(redshifts[i])] [:,0]
    pk = data['kgb']['m']['z='+str(redshifts[i])] [:,1]
    plt.plot(k_h, (pk),"o", color = Colors[l+3],markersize=8 , label = "KGB,  $m$, gauge-tranformed to Newtonian, z="+str(z), alpha=0.9)

# ########
#     k_q = data['class_tk']['z='+str(redshifts[i])][:,0];
#     tk = data['class_tk']['z='+str(redshifts[i])]
#     Normlization = As*(k_q/kp)**(ns-1.);
#     pk = (tk[:,8]-tk[:,9])**2*Normlization ## chi = phi-psi
# #     Normlization = As*(k_q/kp)**(ns-1.);
#     plt.plot(k_q, pk,"-.", color = Colors[l+2] , label = r"Synchronous, hiclass, tk, z="+str(z))

    l=l+1
    


plt.legend()
plt.ylabel(r"$\mathcal{P}$")
plt.xlabel(r"$k[h/Mpc]$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.e-4,1.e0)
plt.ylim(1.e-9,1.e-6)
# Out:
# (1e-09, 1e-06)

# %% [markdown]
# # Background

# %% [markdown]
# ## Particle horizon

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(14,10))


########hiclass########
plt.plot(1+bg[:,0],  bg[:,2] * (bg[-1:,3]) , label = "Particle horizon, hiCLASS")

##########gevolution#########
###########################
c_gev=1.;
h=0.67556;
fourpiG_gevolution = 3./2. /c_gev/c_gev;
gev_to_hiclass_converion = 2./3. * np.sqrt(fourpiG_gevolution);# Boxsize cancels due to tau definition in gev
gev_result = gev_bg[:,1] / gev_to_hiclass_converion
plt.plot(1+(1./gev_bg[:,2]-1),gev_result ,"o", label = "Particle horizon, EQ-evolution")

############################
##########Alessnadro#########
############################
fourpiG_Alessandro = 0.5;
alessandro_to_hiclass_converion = (np.sqrt(2. * fourpiG_Alessandro/3.));
alessandro_result = bg_alessandro[:,9] * alessandro_to_hiclass_converion ;
plt.plot(1+(1./bg_alessandro[:,1]-1), alessandro_result,"-.", label = "Particle horizon, Alessandro")

plt.legend()
# plt.ylabel(r"$$")
plt.xlabel(r"$z$")
# plt.xscale('log')
plt.yscale('log')
plt.xlim(1,100)
plt.ylim(3.e-1,5.e0)



##################################
##################################
##################################

plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(14,10))


hiclass_val = interpolate.interp1d(1+bg[:,0], bg[:,2] * (bg[-1:,3]) )


#####gevolution######
num = -2
rel_diff = np.abs(gev_result[:num]/hiclass_val(1+(1./gev_bg[:num,2]-1)) - 1.)

plt.plot(1+(1./gev_bg[:num,2]-1),rel_diff,"o", label = "Particle horizon, EQ-evolution vs hiclass")


#####hiclass######
num1 = 0
num = -400
rel_diff = np.abs(alessandro_result[num1:num]/hiclass_val(1+(1./bg_alessandro[num1:num,1]-1)) - 1.)
plt.plot(1+(1./bg_alessandro[num1:num,1]-1),rel_diff ,"-.", label = "Particle horizon, Alessandro vs hiclass")

plt.legend()
# plt.ylabel(r"$$")
plt.xlabel(r"$z$")
# plt.xscale('log')
plt.yscale('log')
plt.xlim(1,100)
plt.ylim(1.e-4,0.5)
# Out:
# (0.0001, 0.5)

# %% [markdown]
# ## Hubble function

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(10,8))



###### hiclass results:
#     

plt.plot(1+bg[:,0], bg[:,3]/bg[-1:,3] , label = "$\mathcal{H}$, hiCLASS")

plt.plot(1+(1./gev_bg[:,2]-1), gev_bg[:,3]/gev_bg[:,2], label = "$\mathcal{H}$, EQ-evolution")

plt.plot(1+(1./bg_alessandro[:,1]-1), bg_alessandro[:,2]/bg_alessandro[:,1],"-.", label = "$\mathcal{H}$, Alessandro")


    
plt.legend()
# plt.ylabel(r"$$")
plt.xlabel(r"$z$")
# plt.xscale('log')
plt.yscale('log')
plt.xlim(1,100)
plt.ylim(1.,1.e3)
# Out:
# (1.0, 1000.0)

# %% [markdown]
# # Hubble_prime

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(10,8))



###### hiclass results:
#     

plt.plot(1+bg[:,0], -bg[:,4]/bg[-1:,3]/bg[-1:,3], label = "$\mathcal{H}^\prime$, hiCLASS")


plt.plot(1+(1./bg_alessandro[:,1]-1), -bg_alessandro[:,3]/bg_alessandro[:,1] + bg_alessandro[:,2]**2/bg_alessandro[:,1],"-.", label = "$\mathcal{H}'$, Alessandro")


    
plt.legend()
# plt.ylabel(r"$$")
plt.xlabel(r"$z$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1,500)
plt.ylim(0.2,1.e6)
# Out:
# (0.2, 1000000.0)

# %% [markdown]
# ## scalar field and scalar field' and double prime background

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(10,8))
a_hiclass = 1./(1.+bg[:,0])
Hconf_hiclass = interpolate.interp1d(bg[:,0] ,bg[:,3] * a_hiclass  )


###### hiclass results:
#     
plt.plot(1+bg[:,0], bg[:,29],"*" , label = "$\\varphi$, hiCLASS")
plt.plot(1+(1./gev_bg[:,2]-1), gev_bg[:,4],"s", label = "$\\varphi$,  EQ-evolution")
plt.plot(1+(1./gev_bg[:,2]-1), gev_bg[:,7],"s", label = "$\\varphi$,  EQ-evolution2")

plt.plot(1+(1./bg_alessandro[:,1]-1), bg_alessandro[:,10],"-.", label = "$\\varphi$, Alessandro")

plt.legend()
# plt.ylabel(r"$$")

plt.xscale('log')
plt.yscale('log')
plt.xlim(1,113)
plt.ylim(1.e-3,1.e2)
# Out:
# (0.001, 100.0)

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(10,8))


scalar_p_hiclass = interpolate.interp1d((bg[:,0]), bg[:,29])

###### hiclass results:
#     
h=0.67556
fourpiG_Alessandro = 0.5
plt.plot(1+bg[:,0],  bg[:,30]/(bg[-1:,3]),"*" , label = "$\\varphi'$, hiCLASS")
# plt.plot(1+(1./gev_bg[:,2]-1), gev_bg[:,5], label = "$\\varphi'$,  EQ-evolution")
# plt.plot(1+(1./gev_bg[:,2]-1), gev_bg[:,8],"s", label = "$\\varphi'$,  EQ-evolution2")

plt.plot(1+(1./bg_alessandro[:,1]-1), bg_alessandro[:,11]/np.sqrt(2.* fourpiG_Alessandro/3.0),"-.", label = "$\\varphi'$, Alessandro")

    
plt.legend()
# plt.ylabel(r"$$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1,1.e2)
plt.ylim(1.e-2,1.e0)
# Out:
# (0.01, 1.0)

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(10,8))

###### hiclass results:
#     
h=0.67556
fourpiG_Alessandro = 0.5;

plt.plot(1+bg[:,0], bg[:,31]/bg[-1:,3]/bg[-1:,3],"*", label = "$\\varphi''$, hiCLASS")

plt.plot(1+(1./gev_bg[:,2]-1), gev_bg[:,6], label = "$\\varphi''$,  EQ-evolution")

plt.plot(1+(1./bg_alessandro[:,1]-1), bg_alessandro[:,12]/np.sqrt(2.* fourpiG_Alessandro/3.0)/np.sqrt(2.* fourpiG_Alessandro/3.0),"-.", label = "$\\varphi'$, Alessandro")
    
plt.legend()
# plt.ylabel(r"$$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1,100)
plt.ylim(1.e-1,1.e0)
# Out:
# (0.1, 1.0)

# %% [markdown]
# # Power spectra

# %% [markdown]
# ## Data loading

# %%
# z=[100,50 ];
# gev_pi = [];
# gev_V_pi =[];
# class_tk = [];
# for i in range(np.shape(z)[0]):
#     gev_pi.append(np.loadtxt("./../output/lcdm_pk00"+str(i)+"_pi.dat"))
#     gev_V_pi.append(np.loadtxt("./../output/lcdm_pk00"+str(i)+"_V_pi.dat"))

# %% [markdown]
# ## Scalar field power spectrum

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(12,12))

#########
## scalar_field
#########

Hconf = interpolate.interp1d((1./gev_bg[:,2]) -1.,gev_bg[:,3]*H0)
scalar = interpolate.interp1d((1./gev_bg[:,2]) -1.,gev_bg[:,4])
scalar_p = interpolate.interp1d((1./gev_bg[:,2]) -1.,gev_bg[:,5])
scalar_pp = interpolate.interp1d((1./gev_bg[:,2]) -1.,gev_bg[:,6])


a_hiclass = 1./(1.+bg[:,0])
Hconf_hiclass = interpolate.interp1d(bg[:,0] ,bg[:,3] * a_hiclass  )




###### hiclass results:
redshifts = [100]
for i in range(3):
    alpha = (class_tk[i][:,11] + 6.0 *class_tk[i][:,13] )/(2.*k_q*k_q);
    Vx = class_tk[i][:,5]
    Vx = Vx + alpha; # gauge transfomration
    scalar_field = Vx * Hconf_hiclass(0) * scalar_p(redshifts[i])/(1./(1+redshifts[i])) 
    plt.plot(class_tk[i][:,0], (scalar_field)**2* Normlization , label = "$\delta \phi$, hiCLASS, z="+str(redshifts[i]))

#     plt.plot(k_q,pi_p**2 * Normlization/k_q**3/(2*np.pi),label = "$VX'$, z="+str(i))
    
#     plt.plot(gev_pi[0][:,0],gev_pi[0][:,1],label = "$VX$, z="+str(i))
    plt.plot(gev_V_pi[i][:,0],gev_pi[i][:,1],label = "$\delta \phi$, z="+str(redshifts[i]))
    
plt.legend()
plt.ylabel(r"$P$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.e-3,1.e0)
plt.ylim(1.e-15,1.e-8)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-246-443f921a0728> in <module>
#      29     Vx = class_tk[i][:,5]
#      30     Vx = Vx + alpha; # gauge transfomration
# ---> 31     scalar_field = Vx * Hconf_hiclass(0) * scalar_p(redshifts[i])/(1./(1+redshifts[i]))
#      32     plt.plot(class_tk[i][:,0], (scalar_field)**2* Normlization , label = "$\delta \phi$, hiCLASS, z="+str(redshifts[i]))
#      33
#
# IndexError: list index out of range

# %% [markdown]
# ## phi' power

# %%
###### Normalization factor
As=2.215*1.e-9;
h=0.67556;
kp=0.05/h; 
ns=0.9619;
cs2=1.e-4;
c=2.99792458*1.e5; #Km/s
H0=100*h/c; #H0 in 1/Mpc unit. 0.00022593979933110373
w=-0.9;
k_q = class_tk[0][:,0];


Normlization = As*(k_q/kp)**(ns-1.);

a_hiclass = 1./(1.+bg[:,0])
Hconf_hiclass = interpolate.interp1d(bg[:,0] ,bg[:,3] * a_hiclass  )
# scalar = interpolate.interp1d((1./gev_bg[:,2]) -1.,gev_bg[:,4])
# scalar_p = interpolate.interp1d((1./gev_bg[:,2]) -1.,gev_bg[:,5])
# scalar_pp = interpolate.interp1d((1./gev_bg[:,2]) -1.,gev_bg[:,6])

scalar = interpolate.interp1d(bg[:,0],bg[:,29])
scalar_p = interpolate.interp1d(bg[:,0],bg[:,30])
scalar_pp = interpolate.interp1d(bg[:,0],bg[:,31])

#####################
## scalar_field_prime
#####################

redshifts = [100,50,10]

plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(10,8))


zini = 100
###### hiclass results:
for z in [zini]:
#     zini = 100
    aini = 1./(1+z);
    alpha_prime = (class_tk[0][:,9] + class_tk[0][:,8] -  class_tk[0][:,12]);
    Vx_prime = class_tk[0][:,6] + alpha_prime; # gauge transfomration
    scalar_field_prime = (scalar_p(z)) #+ Vx * (- Hconf_hiclass(z) * scalar_p(z) + scalar_pp(z)))/aini;
# bg[:,30]/Hconf_hiclass(0)

    plt.plot(class_tk[0][:,0], (scalar_field_prime)**2* Normlization, label = "$\delta\phi'$, hiCLASS, z="+str(z))
    plt.plot(gev_V_pi[0][:,0],gev_V_pi[0][:,1],"o",label = r"$\delta\phi'$, z="+str(z))
    
plt.legend()
plt.ylabel(r"$P$")
plt.xscale('log')
# plt.yscale('log')
plt.xlim(1.e-3,1.e0)
# plt.ylim(1.e-19,1.e-11)
# Out:
# (0.001, 1.0)

# %%
# plt.rc('text', usetex=True)
# font = {'family' : 'normal',
#         'weight' : 'bold',
#         'size'   : text_size}

# matplotlib.rc('font', **font)
# plt.figure(figsize=(10,8))



# ###### hiclass results:
# for i in [100]:
    
#     plt.plot(class_tk[0][:,0], (class_tk[0][:,5])**2 * Normlization , label = "$VX$, CLASS, z="+str(i))

# #     plt.plot(k_q,pi_p**2 * Normlization/k_q**3/(2*np.pi),label = "$VX'$, z="+str(i))
    
# #     plt.plot(gev_pi[0][:,0],gev_pi[0][:,1],label = "$VX$, z="+str(i))
# #     plt.plot(gev_V_pi[0][:,0],gev_pi[0][:,1],label = "$VX'$, z="+str(i))
    
# plt.legend()
# plt.ylabel(r"$P$")
# plt.xscale('log')
# plt.yscale('log')
# plt.xlim(6.e-3,1.e-1)
# # plt.ylim(1.e-10,1.e-3)

# %%
# plt.rc('text', usetex=True)
# font = {'family' : 'normal',
#         'weight' : 'bold',
#         'size'   : text_size}

# matplotlib.rc('font', **font)
# plt.figure(figsize=(10,8))

# ###### Normalization factor
# As=2.215*1.e-9;
# h=0.67556;
# kp=0.05/h; 
# ns=0.9619;
# cs2=1.e-4;
# c=2.99792458*1.e5; #Km/s
# H0=100*h/c; #H0 in 1/Mpc unit. 0.00022593979933110373
# w=-0.9;
# def Hubble_conf_Mpc(a):
#     c=2.99792458*1.e5;h=0.67556;H0=100*h/c;w=-0.9;
#     Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
#     Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0;
#     Omega_rad=9.1671353942930788e-05; Omega_kessence=1.-Omega_m-Omega_rad;
#     return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_kessence*(a**(-3*(1+w))))*a
# Normlization=As*(k_q/kp)**(ns-1.);

# ###### hiclass results:
# for i in [100]:
# #     k_q *=h
#     plt.plot(k_q,scalar_field**2*Normlization, label = "$VX$, z="+str(i))

# #     plt.plot(k_q,pi_p**2 * Normlization/k_q**3/(2*np.pi),label = "$VX'$, z="+str(i))
    
#     plt.plot(gev_pi[0][:,0],gev_pi[0][:,1],label = "$VX$, z="+str(i))
# #     plt.plot(gev_V_pi[0][:,0],gev_V_pi[0][:,1],label = "$VX'$, z="+str(i))
    
# plt.legend()
# plt.ylabel(r"$P$")
# plt.xscale('log')
# plt.yscale('log')
# plt.xlim(1.e-2,1)
# plt.ylim(1.e-14,1.e-6)
# Out:
# (1e-14, 1e-06)

# %% [markdown]
# # Test

# %%
z_gev=[100];
gev_pi = [];
gev_V_pi =[];
for i in range(np.shape(z_gev)[0]):
    gev_pi.append(np.loadtxt("./../../EQevolution/output/lcdm_pk00"+str(i)+"_pi.dat"))
    gev_V_pi.append(np.loadtxt("./../../EQevolution/output/lcdm_pk00"+str(i)+"_V_pi.dat"))
gev_bg= np.loadtxt("./../../EQevolution/output/quintessence_background.dat")

# %%
###### Normalization factor
As=2.215*1.e-9;
h=0.67556;
kp=0.05/h; 
ns=0.9619;
cs2=1.e-4;
c=2.99792458*1.e5; #Km/s
H0=100*h/c; #H0 in 1/Mpc unit. 0.00022593979933110373
w=-0.9;
k_q = cosmo.get_transfer(i)['k (h/Mpc)'];
Normlization=As*(k_q/kp)**(ns-1.);

zini = 100.
aini = 1./(1+zini);

#########
## scalar_field
#########
Hconf = interpolate.interp1d((1./gev_bg[:,2]) -1.,gev_bg[:,3]*H0)
scalar = interpolate.interp1d((1./gev_bg[:,2]) -1.,gev_bg[:,4])
scalar_p = interpolate.interp1d((1./gev_bg[:,2]) -1.,gev_bg[:,5])
scalar_pp = interpolate.interp1d((1./gev_bg[:,2]) -1.,gev_bg[:,6])
Vx = cosmo.get_transfer(i)['vx_smg']
alpha = (cosmo.get_transfer(i)['h_prime'] + 6.0 * cosmo.get_transfer(i)['eta_prime'])/(2.*k_q*k_q);
Vx = Vx + 0. * alpha; # gauge transfomration
# scalar_field = Vx * Hconf(0.) * scalar_p(zini)/aini;
#########
## scalar_field_prime
#########
alpha_prime = (cosmo.get_transfer(i)['psi'] + cosmo.get_transfer(i)['phi'] -  cosmo.get_transfer(i)['eta']);
Vx_prime = cosmo.get_transfer(i)['vx_prime_smg'] + 0. * alpha_prime; # gauge transfomration
# scalar_field_prime = Vx_prime * scalar_p(zini)/aini + scalar_field * (-Hconf(zini) + scalar_pp(zini)/scalar_p(zini));

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(10,8))



###### hiclass results:
for i in [100]:
    
    plt.plot(k_q,Vx_prime**2 , label = "$VX$, z="+str(i))

#     plt.plot(k_q,pi_p**2 * Normlization/k_q**3/(2*np.pi),label = "$VX'$, z="+str(i))
    
#     plt.plot(gev_pi[0][:,0],gev_pi[0][:,1],label = "$VX$, z="+str(i))
    plt.plot(gev_V_pi[0][:,0],gev_V_pi[0][:,1],label = "$VX'$, z="+str(i))
    
plt.legend()
plt.ylabel(r"$P$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(2.e-4,0.01)
# plt.ylim(1.e-24,1.e-12)
# Out:
# (0.0002, 0.01)

# %% [markdown]
# # pi comparison

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(10,8))

###### Normalization factor
As=2.215*1.e-9;
h=0.67556;
kp=0.05/h; 
ns=0.9619;
cs2=1.e-4;
c=2.99792458*1.e5; #Km/s
H0=100*h/c; #H0 in 1/Mpc unit. 0.00022593979933110373
w=-0.9;
def Hubble_conf_Mpc(a):
    c=2.99792458*1.e5;h=0.67556;H0=100*h/c;w=-0.9;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0;
    Omega_rad=9.1671353942930788e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_kessence*(a**(-3*(1+w))))*a
Normlization=As*(k_q/kp)**(ns-1.);


###### hiclass results:
for i in [10,0]:
    k_q = cosmo.get_transfer(i)['k (h/Mpc)'];
    pi = cosmo.get_transfer(i)['d_V_x_smg'] + cosmo.get_transfer(i)['alpha'];
    plt.plot(k_q,pi**2 * Normlization/k_q**3/(2*np.pi),label = "z="+str(i))
    pi = cosmo.get_transfer(i)['t_V_x_smg'] ;
    plt.plot(k_q,pi**2 * Normlization/k_q**3/(2*np.pi),label = "z="+str(i))

###### EQ-evolution results:
# for i in [3,6]:
#     a =1/(1+z_gev[i]);
#     k = gev_result_pi[i][:,0];
#     plt.plot(k,gev_result_pi[i][:,1]/Hubble_conf_Mpc(a)/Hubble_conf_Mpc(a),"o",label="z="+str(z_gev[i]))

plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.e-5,1)
# Out:
# (1e-05, 1)

# %% [markdown]
# # V_pi comparison

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(10,8))

###### Normalization factor
As=2.215*1.e-9;
h=0.67556;
kp=0.05/h; 
ns=0.9619;
cs2=1.e-4;
c=2.99792458*1.e5; #Km/s
H0=100*h/c; #H0 in 1/Mpc unit. 0.00022593979933110373
w=-0.9;
def Hubble_conf_Mpc(a):
    c=2.99792458*1.e5;h=0.67556;H0=100*h/c;w=-0.9;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0;
    Omega_rad=9.1671353942930788e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_kessence*(a**(-3*(1+w))))*a
Normlization=As*(k_q/kp)**(ns-1.);


###### hiclass results:
for i in [10,0]:
    k_q = cosmo.get_transfer(i)['k (h/Mpc)'];
    v_pi = cosmo.get_transfer(i)['vx_prime_smg']
    plt.plot(k_q,v_pi**2 * Normlization,label = "z="+str(i))

###### EQ-evolution results:
for i in [3,6]:
    a =1/(1+z_gev[i]);
    k = gev_result_V_pi[i][:,0];
    plt.plot(k,gev_result_V_pi[i][:,1],"o",label="z="+str(z_gev[i]))

plt.legend()
plt.ylabel(r"$P_{V_{\pi}}$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.e-2,1)
# Out:
# (0.01, 1)

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)
plt.figure(figsize=(10,8))

###### Normalization factor
As=2.215*1.e-9;
h=0.67556;
kp=0.05/h; 
ns=0.9619;
cs2=1.e-4;
c=2.99792458*1.e5; #Km/s
H0=100*h/c; #H0 in 1/Mpc unit. 0.00022593979933110373
w=-0.9;
def Hubble_conf_Mpc(a):
    c=2.99792458*1.e5;h=0.67556;H0=100*h/c;w=-0.9;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0;
    Omega_rad=9.1671353942930788e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_kessence*(a**(-3*(1+w))))*a
Normlization=As*(k_q/kp)**(ns-1.);


###### EQ-evolution results:
for i in [3,6]:
    a =1/(1+z_gev[i]);
    k = gev_result_V_pi[i][:,0];
    plt.plot(k,gev_result_V_pi[i][:,1],"o",label="z="+str(z_gev[i]))
    plt.plot(k,gev_result_pi[i][:,1],"o",label="z="+str(z_gev[i]))

plt.legend()
plt.ylabel(r"$P_{V_{\pi}}$")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.e-2,1)
# Out:
# (0.01, 1)

# %%
N_last = - 35

plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}

matplotlib.rc('font', **font)

borders=[-15,0,-0.1,1.1]

f, (ax1, ax1_w, ax2, ax2_w) = plt.subplots(4, sharex=True, sharey=False ,figsize=(24,30),gridspec_kw = {'height_ratios':[1,0.3,1,0.3]})
p1=ax1.plot(np.log(1/(1+bkg_fe['z'])),bkg_fe['(.)rho_smg']/bkg_fe['(.)rho_crit'],label='$\Omega_{\phi}$')
color=p1[0].get_color()
ax1.plot(np.log(1/(1+bkg_lcdm['z'])),(bkg_lcdm['(.)rho_lambda'])/bkg_lcdm['(.)rho_crit'],linestyle='--',label='$\Omega_\Lambda$',color=color)
p2=ax1.plot(np.log(1/(1+bkg_fe['z'])),(bkg_fe['(.)rho_g']+bkg_fe['(.)rho_ur'])/bkg_fe['(.)rho_crit'],label='$\Omega_{r}$')
color=p2[0].get_color()
ax1.plot(np.log(1/(1+bkg_lcdm['z'])),(bkg_lcdm['(.)rho_g']+bkg_lcdm['(.)rho_ur'])/bkg_lcdm['(.)rho_crit'],linestyle='dashed',color=color)
p3=ax1.plot(np.log(1/(1+bkg_fe['z'])),(bkg_fe['(.)rho_b'])/bkg_fe['(.)rho_crit'],label='$\Omega_{b}$')
color=p3[0].get_color()
ax1.plot(np.log(1/(1+bkg_lcdm['z'])),(bkg_lcdm['(.)rho_b'])/bkg_lcdm['(.)rho_crit'],linestyle='dashed',color=color)
p4=ax1.plot(np.log(1/(1+bkg_fe['z'])),(bkg_fe['(.)rho_cdm'])/bkg_fe['(.)rho_crit'],label='$\Omega_{cdm}$')
color=p4[0].get_color()
ax1.plot(np.log(1/(1+bkg_lcdm['z'])),(bkg_lcdm['(.)rho_cdm'])/bkg_lcdm['(.)rho_crit'],linestyle='dashed',color=color)

ax1.set_ylabel("$\Omega_i$")
ax1.legend(loc='upper left')
ax1.grid(True)
ax1.axis([N_last,0,-0.1,1.1])
ax1.set_xlim(-15,0)

p1_w=ax1_w.plot(np.log(1/(1+bkg_fe['z'])),bkg_fe['(.)p_smg']/bkg_fe['(.)rho_smg'])
ax1_w.set_ylabel("$\omega_\phi$")
ax1_w.grid(True)
ax1_w.axhline(1.1, color="black", linewidth=4)
ax1_w.axhline(-1.1, color="black", linewidth=8)
ax1_w.axis([N_last,0,-1.1,1.1])

left, width = .25, .5
bottom, height = .25, .5
right = left + width
top = bottom + height
ax1.text(1.02, 0.3*(bottom+top), '$\\gamma=0.2$', horizontalalignment='center', verticalalignment='center', rotation=270, transform=ax1.transAxes)

p1=ax2.plot(np.log(1/(1+bkg_fe2['z'])),bkg_fe2['(.)rho_smg']/bkg_fe2['(.)rho_crit'],label='$\Omega_{\phi}$')
color=p1[0].get_color()
ax2.plot(np.log(1/(1+bkg_lcdm['z'])),(bkg_lcdm['(.)rho_lambda'])/bkg_lcdm['(.)rho_crit'],linestyle='--',label='$\Omega_\Lambda$',color=color)
p2=ax2.plot(np.log(1/(1+bkg_fe2['z'])),(bkg_fe2['(.)rho_g']+bkg_fe2['(.)rho_ur'])/bkg_fe2['(.)rho_crit'],label='$\Omega_{r}$')
color=p2[0].get_color()
ax2.plot(np.log(1/(1+bkg_lcdm['z'])),(bkg_lcdm['(.)rho_g']+bkg_lcdm['(.)rho_ur'])/bkg_lcdm['(.)rho_crit'],linestyle='dashed',color=color)
p3=ax2.plot(np.log(1/(1+bkg_fe2['z'])),(bkg_fe2['(.)rho_b'])/bkg_fe2['(.)rho_crit'],label='$\Omega_{b}$')
color=p3[0].get_color()
ax2.plot(np.log(1/(1+bkg_lcdm['z'])),(bkg_lcdm['(.)rho_b'])/bkg_lcdm['(.)rho_crit'],linestyle='dashed',color=color)
p4=ax2.plot(np.log(1/(1+bkg_fe2['z'])),(bkg_fe2['(.)rho_cdm'])/bkg_fe2['(.)rho_crit'],label='$\Omega_{cdm}$')
color=p4[0].get_color()
ax2.plot(np.log(1/(1+bkg_lcdm['z'])),(bkg_lcdm['(.)rho_cdm'])/bkg_lcdm['(.)rho_crit'],linestyle='dashed',color=color)
#ax2.set_xlabel("log($a$)")
ax2.set_ylabel("$\Omega_i$")
ax2.legend(loc='upper left')
ax2.grid(True)
ax2.axis([N_last,0,-0.1,1.1])

ax2.text(1.02, 0.3*(bottom+top), '$\\gamma=-0.2$', horizontalalignment='center', verticalalignment='center', rotation=270, transform=ax2.transAxes)

p2_w=ax2_w.plot(np.log(1/(1+bkg_fe2['z'])),bkg_fe2['(.)p_smg']/bkg_fe2['(.)rho_smg'])
ax2_w.set_ylabel("$\omega_\phi$")
ax2_w.set_xlabel("ln($a$)")
ax2_w.axhline(1.1, color="black", linewidth=4)
ax2_w.grid(True)
ax2_w.axis([N_last,0,-1.1,1.1])

f.subplots_adjust(hspace=0)
f.figsize=(24,24)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

#plt.savefig('/Users/Alessandro/Documents/Google Drive/Uni/Laurea Magistrale/Prova finale/Tesi/Img/jupyter/quint_density.eps',bbox_inches='tight',format='eps',dpi=1000)
#plt.savefig('/Users/Alessandro/Documents/Google Drive/Uni/Laurea Magistrale/Prova finale/Tesi/Img/jupyter/quint_density.pdf',bbox_inches='tight')
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
